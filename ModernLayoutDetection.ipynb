# %%
import os

from BDRC.inference import ModernBookFormatLayoutDetection
from BDRC.utils import read_layout_model_config

# %%
# load model 
model_config_file = "Models/BDRC/ModernBookFormat/config.json"
model_config = read_layout_model_config(model_config_file)
modern_layout_detection = ModernBookFormatLayoutDetection(model_config)

# %%
# input/output dir
volume_path = "Data/Modern/W1KG14507"
output_dir = os.path.join(volume_path, "Output")

modern_layout_detection.run(volume_path, output_dir, filter_classes=["header", "footer"])
# Out:
# 100%|██████████| 5/5 [00:21<00:00,  4.32s/it]
