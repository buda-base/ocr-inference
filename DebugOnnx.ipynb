# %%
import onnx

# %%
onnx_model_file = "Models/BDRC/PhotiLines/PhotiLines.onnx"

onnx_model = onnx.load(onnx_model_file)

for i in range(len(onnx_model.graph.node)):
	for j in range(len(onnx_model.graph.node[i].input)):
			print('-'*60)
			print(onnx_model.graph.node[i].name)
			print(onnx_model.graph.node[i].input)
			print(onnx_model.graph.node[i].output)

	for j in range(len(onnx_model.graph.node[i].output)):
			print('-'*60)
			print(onnx_model.graph.node[i].name)
			print(onnx_model.graph.node[i].input)
			print(onnx_model.graph.node[i].output)

for i in range(len(onnx_model.graph.input)):
		print('-'*60)
		print(onnx_model.graph.input[i])
	
for i in range(len(onnx_model.graph.output)):
		print('-'*60)
		print(onnx_model.graph.output[i])
# Out:
# ------------------------------------------------------------
# Identity_0
# ['onnx::Resize_602']
# ['onnx::Resize_603']
# ------------------------------------------------------------
# Identity_0
# ['onnx::Resize_602']
# ['onnx::Resize_603']
# ------------------------------------------------------------
# Conv_1
# ['input', 'onnx::Conv_468', 'onnx::Conv_469']
# ['input.3']
# ------------------------------------------------------------
# Conv_1
# ['input', 'onnx::Conv_468', 'onnx::Conv_469']
# ['input.3']
# ------------------------------------------------------------
# Conv_1
# ['input', 'onnx::Conv_468', 'onnx::Conv_469']
# ['input.3']
# ------------------------------------------------------------
# Conv_1
# ['input', 'onnx::Conv_468', 'onnx::Conv_469']
# ['input.3']
# ------------------------------------------------------------
# Relu_2
# ['input.3']
# ['onnx::MaxPool_280']
# ------------------------------------------------------------
# Relu_2
# ['input.3']
# ['onnx::MaxPool_280']
# ------------------------------------------------------------
# MaxPool_3
# ['onnx::MaxPool_280']
# ['input.7']
# ------------------------------------------------------------
# MaxPool_3
# ['onnx::MaxPool_280']
# ['input.7']
# ------------------------------------------------------------
# Conv_4
# ['input.7', 'onnx::Conv_471', 'onnx::Conv_472']
# ['input.15']
# ------------------------------------------------------------
# Conv_4
# ['input.7', 'onnx::Conv_471', 'onnx::Conv_472']
# ['input.15']
# ------------------------------------------------------------
# Conv_4
# ['input.7', 'onnx::Conv_471', 'onnx::Conv_472']
# ['input.15']
# ------------------------------------------------------------
# Conv_4
# ['input.7', 'onnx::Conv_471', 'onnx::Conv_472']
# ['input.15']
# ------------------------------------------------------------
# Relu_5
# ['input.15']
# ['onnx::Conv_284']
# ------------------------------------------------------------
# Relu_5
# ['input.15']
# ['onnx::Conv_284']
# ------------------------------------------------------------
# Conv_6
# ['onnx::Conv_284', 'onnx::Conv_474', 'onnx::Conv_475']
# ['onnx::Add_473']
# ------------------------------------------------------------
# Conv_6
# ['onnx::Conv_284', 'onnx::Conv_474', 'onnx::Conv_475']
# ['onnx::Add_473']
# ------------------------------------------------------------
# Conv_6
# ['onnx::Conv_284', 'onnx::Conv_474', 'onnx::Conv_475']
# ['onnx::Add_473']
# ------------------------------------------------------------
# Conv_6
# ['onnx::Conv_284', 'onnx::Conv_474', 'onnx::Conv_475']
# ['onnx::Add_473']
# ------------------------------------------------------------
# Add_7
# ['onnx::Add_473', 'input.7']
# ['onnx::Relu_287']
# ------------------------------------------------------------
# Add_7
# ['onnx::Add_473', 'input.7']
# ['onnx::Relu_287']
# ------------------------------------------------------------
# Add_7
# ['onnx::Add_473', 'input.7']
# ['onnx::Relu_287']
# ------------------------------------------------------------
# Relu_8
# ['onnx::Relu_287']
# ['input.23']
# ------------------------------------------------------------
# Relu_8
# ['onnx::Relu_287']
# ['input.23']
# ------------------------------------------------------------
# Conv_9
# ['input.23', 'onnx::Conv_477', 'onnx::Conv_478']
# ['input.31']
# ------------------------------------------------------------
# Conv_9
# ['input.23', 'onnx::Conv_477', 'onnx::Conv_478']
# ['input.31']
# ------------------------------------------------------------
# Conv_9
# ['input.23', 'onnx::Conv_477', 'onnx::Conv_478']
# ['input.31']
# ------------------------------------------------------------
# Conv_9
# ['input.23', 'onnx::Conv_477', 'onnx::Conv_478']
# ['input.31']
# ------------------------------------------------------------
# Relu_10
# ['input.31']
# ['onnx::Conv_291']
# ------------------------------------------------------------
# Relu_10
# ['input.31']
# ['onnx::Conv_291']
# ------------------------------------------------------------
# Conv_11
# ['onnx::Conv_291', 'onnx::Conv_480', 'onnx::Conv_481']
# ['onnx::Add_479']
# ------------------------------------------------------------
# Conv_11
# ['onnx::Conv_291', 'onnx::Conv_480', 'onnx::Conv_481']
# ['onnx::Add_479']
# ------------------------------------------------------------
# Conv_11
# ['onnx::Conv_291', 'onnx::Conv_480', 'onnx::Conv_481']
# ['onnx::Add_479']
# ------------------------------------------------------------
# Conv_11
# ['onnx::Conv_291', 'onnx::Conv_480', 'onnx::Conv_481']
# ['onnx::Add_479']
# ------------------------------------------------------------
# Add_12
# ['onnx::Add_479', 'input.23']
# ['onnx::Relu_294']
# ------------------------------------------------------------
# Add_12
# ['onnx::Add_479', 'input.23']
# ['onnx::Relu_294']
# ------------------------------------------------------------
# Add_12
# ['onnx::Add_479', 'input.23']
# ['onnx::Relu_294']
# ------------------------------------------------------------
# Relu_13
# ['onnx::Relu_294']
# ['input.39']
# ------------------------------------------------------------
# Relu_13
# ['onnx::Relu_294']
# ['input.39']
# ------------------------------------------------------------
# Conv_14
# ['input.39', 'onnx::Conv_483', 'onnx::Conv_484']
# ['input.47']
# ------------------------------------------------------------
# Conv_14
# ['input.39', 'onnx::Conv_483', 'onnx::Conv_484']
# ['input.47']
# ------------------------------------------------------------
# Conv_14
# ['input.39', 'onnx::Conv_483', 'onnx::Conv_484']
# ['input.47']
# ------------------------------------------------------------
# Conv_14
# ['input.39', 'onnx::Conv_483', 'onnx::Conv_484']
# ['input.47']
# ------------------------------------------------------------
# Relu_15
# ['input.47']
# ['onnx::Conv_298']
# ------------------------------------------------------------
# Relu_15
# ['input.47']
# ['onnx::Conv_298']
# ------------------------------------------------------------
# Conv_16
# ['onnx::Conv_298', 'onnx::Conv_486', 'onnx::Conv_487']
# ['onnx::Add_485']
# ------------------------------------------------------------
# Conv_16
# ['onnx::Conv_298', 'onnx::Conv_486', 'onnx::Conv_487']
# ['onnx::Add_485']
# ------------------------------------------------------------
# Conv_16
# ['onnx::Conv_298', 'onnx::Conv_486', 'onnx::Conv_487']
# ['onnx::Add_485']
# ------------------------------------------------------------
# Conv_16
# ['onnx::Conv_298', 'onnx::Conv_486', 'onnx::Conv_487']
# ['onnx::Add_485']
# ------------------------------------------------------------
# Add_17
# ['onnx::Add_485', 'input.39']
# ['onnx::Relu_301']
# ------------------------------------------------------------
# Add_17
# ['onnx::Add_485', 'input.39']
# ['onnx::Relu_301']
# ------------------------------------------------------------
# Add_17
# ['onnx::Add_485', 'input.39']
# ['onnx::Relu_301']
# ------------------------------------------------------------
# Relu_18
# ['onnx::Relu_301']
# ['input.55']
# ------------------------------------------------------------
# Relu_18
# ['onnx::Relu_301']
# ['input.55']
# ------------------------------------------------------------
# Conv_19
# ['input.55', 'onnx::Conv_489', 'onnx::Conv_490']
# ['input.63']
# ------------------------------------------------------------
# Conv_19
# ['input.55', 'onnx::Conv_489', 'onnx::Conv_490']
# ['input.63']
# ------------------------------------------------------------
# Conv_19
# ['input.55', 'onnx::Conv_489', 'onnx::Conv_490']
# ['input.63']
# ------------------------------------------------------------
# Conv_19
# ['input.55', 'onnx::Conv_489', 'onnx::Conv_490']
# ['input.63']
# ------------------------------------------------------------
# Relu_20
# ['input.63']
# ['onnx::Conv_305']
# ------------------------------------------------------------
# Relu_20
# ['input.63']
# ['onnx::Conv_305']
# ------------------------------------------------------------
# Conv_21
# ['onnx::Conv_305', 'onnx::Conv_492', 'onnx::Conv_493']
# ['onnx::Add_491']
# ------------------------------------------------------------
# Conv_21
# ['onnx::Conv_305', 'onnx::Conv_492', 'onnx::Conv_493']
# ['onnx::Add_491']
# ------------------------------------------------------------
# Conv_21
# ['onnx::Conv_305', 'onnx::Conv_492', 'onnx::Conv_493']
# ['onnx::Add_491']
# ------------------------------------------------------------
# Conv_21
# ['onnx::Conv_305', 'onnx::Conv_492', 'onnx::Conv_493']
# ['onnx::Add_491']
# ------------------------------------------------------------
# Conv_22
# ['input.55', 'onnx::Conv_495', 'onnx::Conv_496']
# ['onnx::Add_494']
# ------------------------------------------------------------
# Conv_22
# ['input.55', 'onnx::Conv_495', 'onnx::Conv_496']
# ['onnx::Add_494']
# ------------------------------------------------------------
# Conv_22
# ['input.55', 'onnx::Conv_495', 'onnx::Conv_496']
# ['onnx::Add_494']
# ------------------------------------------------------------
# Conv_22
# ['input.55', 'onnx::Conv_495', 'onnx::Conv_496']
# ['onnx::Add_494']
# ------------------------------------------------------------
# Add_23
# ['onnx::Add_491', 'onnx::Add_494']
# ['onnx::Relu_310']
# ------------------------------------------------------------
# Add_23
# ['onnx::Add_491', 'onnx::Add_494']
# ['onnx::Relu_310']
# ------------------------------------------------------------
# Add_23
# ['onnx::Add_491', 'onnx::Add_494']
# ['onnx::Relu_310']
# ------------------------------------------------------------
# Relu_24
# ['onnx::Relu_310']
# ['input.75']
# ------------------------------------------------------------
# Relu_24
# ['onnx::Relu_310']
# ['input.75']
# ------------------------------------------------------------
# Conv_25
# ['input.75', 'onnx::Conv_498', 'onnx::Conv_499']
# ['input.83']
# ------------------------------------------------------------
# Conv_25
# ['input.75', 'onnx::Conv_498', 'onnx::Conv_499']
# ['input.83']
# ------------------------------------------------------------
# Conv_25
# ['input.75', 'onnx::Conv_498', 'onnx::Conv_499']
# ['input.83']
# ------------------------------------------------------------
# Conv_25
# ['input.75', 'onnx::Conv_498', 'onnx::Conv_499']
# ['input.83']
# ------------------------------------------------------------
# Relu_26
# ['input.83']
# ['onnx::Conv_314']
# ------------------------------------------------------------
# Relu_26
# ['input.83']
# ['onnx::Conv_314']
# ------------------------------------------------------------
# Conv_27
# ['onnx::Conv_314', 'onnx::Conv_501', 'onnx::Conv_502']
# ['onnx::Add_500']
# ------------------------------------------------------------
# Conv_27
# ['onnx::Conv_314', 'onnx::Conv_501', 'onnx::Conv_502']
# ['onnx::Add_500']
# ------------------------------------------------------------
# Conv_27
# ['onnx::Conv_314', 'onnx::Conv_501', 'onnx::Conv_502']
# ['onnx::Add_500']
# ------------------------------------------------------------
# Conv_27
# ['onnx::Conv_314', 'onnx::Conv_501', 'onnx::Conv_502']
# ['onnx::Add_500']
# ------------------------------------------------------------
# Add_28
# ['onnx::Add_500', 'input.75']
# ['onnx::Relu_317']
# ------------------------------------------------------------
# Add_28
# ['onnx::Add_500', 'input.75']
# ['onnx::Relu_317']
# ------------------------------------------------------------
# Add_28
# ['onnx::Add_500', 'input.75']
# ['onnx::Relu_317']
# ------------------------------------------------------------
# Relu_29
# ['onnx::Relu_317']
# ['input.91']
# ------------------------------------------------------------
# Relu_29
# ['onnx::Relu_317']
# ['input.91']
# ------------------------------------------------------------
# Conv_30
# ['input.91', 'onnx::Conv_504', 'onnx::Conv_505']
# ['input.99']
# ------------------------------------------------------------
# Conv_30
# ['input.91', 'onnx::Conv_504', 'onnx::Conv_505']
# ['input.99']
# ------------------------------------------------------------
# Conv_30
# ['input.91', 'onnx::Conv_504', 'onnx::Conv_505']
# ['input.99']
# ------------------------------------------------------------
# Conv_30
# ['input.91', 'onnx::Conv_504', 'onnx::Conv_505']
# ['input.99']
# ------------------------------------------------------------
# Relu_31
# ['input.99']
# ['onnx::Conv_321']
# ------------------------------------------------------------
# Relu_31
# ['input.99']
# ['onnx::Conv_321']
# ------------------------------------------------------------
# Conv_32
# ['onnx::Conv_321', 'onnx::Conv_507', 'onnx::Conv_508']
# ['onnx::Add_506']
# ------------------------------------------------------------
# Conv_32
# ['onnx::Conv_321', 'onnx::Conv_507', 'onnx::Conv_508']
# ['onnx::Add_506']
# ------------------------------------------------------------
# Conv_32
# ['onnx::Conv_321', 'onnx::Conv_507', 'onnx::Conv_508']
# ['onnx::Add_506']
# ------------------------------------------------------------
# Conv_32
# ['onnx::Conv_321', 'onnx::Conv_507', 'onnx::Conv_508']
# ['onnx::Add_506']
# ------------------------------------------------------------
# Add_33
# ['onnx::Add_506', 'input.91']
# ['onnx::Relu_324']
# ------------------------------------------------------------
# Add_33
# ['onnx::Add_506', 'input.91']
# ['onnx::Relu_324']
# ------------------------------------------------------------
# Add_33
# ['onnx::Add_506', 'input.91']
# ['onnx::Relu_324']
# ------------------------------------------------------------
# Relu_34
# ['onnx::Relu_324']
# ['input.107']
# ------------------------------------------------------------
# Relu_34
# ['onnx::Relu_324']
# ['input.107']
# ------------------------------------------------------------
# Conv_35
# ['input.107', 'onnx::Conv_510', 'onnx::Conv_511']
# ['input.115']
# ------------------------------------------------------------
# Conv_35
# ['input.107', 'onnx::Conv_510', 'onnx::Conv_511']
# ['input.115']
# ------------------------------------------------------------
# Conv_35
# ['input.107', 'onnx::Conv_510', 'onnx::Conv_511']
# ['input.115']
# ------------------------------------------------------------
# Conv_35
# ['input.107', 'onnx::Conv_510', 'onnx::Conv_511']
# ['input.115']
# ------------------------------------------------------------
# Relu_36
# ['input.115']
# ['onnx::Conv_328']
# ------------------------------------------------------------
# Relu_36
# ['input.115']
# ['onnx::Conv_328']
# ------------------------------------------------------------
# Conv_37
# ['onnx::Conv_328', 'onnx::Conv_513', 'onnx::Conv_514']
# ['onnx::Add_512']
# ------------------------------------------------------------
# Conv_37
# ['onnx::Conv_328', 'onnx::Conv_513', 'onnx::Conv_514']
# ['onnx::Add_512']
# ------------------------------------------------------------
# Conv_37
# ['onnx::Conv_328', 'onnx::Conv_513', 'onnx::Conv_514']
# ['onnx::Add_512']
# ------------------------------------------------------------
# Conv_37
# ['onnx::Conv_328', 'onnx::Conv_513', 'onnx::Conv_514']
# ['onnx::Add_512']
# ------------------------------------------------------------
# Add_38
# ['onnx::Add_512', 'input.107']
# ['onnx::Relu_331']
# ------------------------------------------------------------
# Add_38
# ['onnx::Add_512', 'input.107']
# ['onnx::Relu_331']
# ------------------------------------------------------------
# Add_38
# ['onnx::Add_512', 'input.107']
# ['onnx::Relu_331']
# ------------------------------------------------------------
# Relu_39
# ['onnx::Relu_331']
# ['input.123']
# ------------------------------------------------------------
# Relu_39
# ['onnx::Relu_331']
# ['input.123']
# ------------------------------------------------------------
# Conv_40
# ['input.123', 'onnx::Conv_516', 'onnx::Conv_517']
# ['input.131']
# ------------------------------------------------------------
# Conv_40
# ['input.123', 'onnx::Conv_516', 'onnx::Conv_517']
# ['input.131']
# ------------------------------------------------------------
# Conv_40
# ['input.123', 'onnx::Conv_516', 'onnx::Conv_517']
# ['input.131']
# ------------------------------------------------------------
# Conv_40
# ['input.123', 'onnx::Conv_516', 'onnx::Conv_517']
# ['input.131']
# ------------------------------------------------------------
# Relu_41
# ['input.131']
# ['onnx::Conv_335']
# ------------------------------------------------------------
# Relu_41
# ['input.131']
# ['onnx::Conv_335']
# ------------------------------------------------------------
# Conv_42
# ['onnx::Conv_335', 'onnx::Conv_519', 'onnx::Conv_520']
# ['onnx::Add_518']
# ------------------------------------------------------------
# Conv_42
# ['onnx::Conv_335', 'onnx::Conv_519', 'onnx::Conv_520']
# ['onnx::Add_518']
# ------------------------------------------------------------
# Conv_42
# ['onnx::Conv_335', 'onnx::Conv_519', 'onnx::Conv_520']
# ['onnx::Add_518']
# ------------------------------------------------------------
# Conv_42
# ['onnx::Conv_335', 'onnx::Conv_519', 'onnx::Conv_520']
# ['onnx::Add_518']
# ------------------------------------------------------------
# Conv_43
# ['input.123', 'onnx::Conv_522', 'onnx::Conv_523']
# ['onnx::Add_521']
# ------------------------------------------------------------
# Conv_43
# ['input.123', 'onnx::Conv_522', 'onnx::Conv_523']
# ['onnx::Add_521']
# ------------------------------------------------------------
# Conv_43
# ['input.123', 'onnx::Conv_522', 'onnx::Conv_523']
# ['onnx::Add_521']
# ------------------------------------------------------------
# Conv_43
# ['input.123', 'onnx::Conv_522', 'onnx::Conv_523']
# ['onnx::Add_521']
# ------------------------------------------------------------
# Add_44
# ['onnx::Add_518', 'onnx::Add_521']
# ['onnx::Relu_340']
# ------------------------------------------------------------
# Add_44
# ['onnx::Add_518', 'onnx::Add_521']
# ['onnx::Relu_340']
# ------------------------------------------------------------
# Add_44
# ['onnx::Add_518', 'onnx::Add_521']
# ['onnx::Relu_340']
# ------------------------------------------------------------
# Relu_45
# ['onnx::Relu_340']
# ['input.143']
# ------------------------------------------------------------
# Relu_45
# ['onnx::Relu_340']
# ['input.143']
# ------------------------------------------------------------
# Conv_46
# ['input.143', 'onnx::Conv_525', 'onnx::Conv_526']
# ['input.151']
# ------------------------------------------------------------
# Conv_46
# ['input.143', 'onnx::Conv_525', 'onnx::Conv_526']
# ['input.151']
# ------------------------------------------------------------
# Conv_46
# ['input.143', 'onnx::Conv_525', 'onnx::Conv_526']
# ['input.151']
# ------------------------------------------------------------
# Conv_46
# ['input.143', 'onnx::Conv_525', 'onnx::Conv_526']
# ['input.151']
# ------------------------------------------------------------
# Relu_47
# ['input.151']
# ['onnx::Conv_344']
# ------------------------------------------------------------
# Relu_47
# ['input.151']
# ['onnx::Conv_344']
# ------------------------------------------------------------
# Conv_48
# ['onnx::Conv_344', 'onnx::Conv_528', 'onnx::Conv_529']
# ['onnx::Add_527']
# ------------------------------------------------------------
# Conv_48
# ['onnx::Conv_344', 'onnx::Conv_528', 'onnx::Conv_529']
# ['onnx::Add_527']
# ------------------------------------------------------------
# Conv_48
# ['onnx::Conv_344', 'onnx::Conv_528', 'onnx::Conv_529']
# ['onnx::Add_527']
# ------------------------------------------------------------
# Conv_48
# ['onnx::Conv_344', 'onnx::Conv_528', 'onnx::Conv_529']
# ['onnx::Add_527']
# ------------------------------------------------------------
# Add_49
# ['onnx::Add_527', 'input.143']
# ['onnx::Relu_347']
# ------------------------------------------------------------
# Add_49
# ['onnx::Add_527', 'input.143']
# ['onnx::Relu_347']
# ------------------------------------------------------------
# Add_49
# ['onnx::Add_527', 'input.143']
# ['onnx::Relu_347']
# ------------------------------------------------------------
# Relu_50
# ['onnx::Relu_347']
# ['input.159']
# ------------------------------------------------------------
# Relu_50
# ['onnx::Relu_347']
# ['input.159']
# ------------------------------------------------------------
# Conv_51
# ['input.159', 'onnx::Conv_531', 'onnx::Conv_532']
# ['input.167']
# ------------------------------------------------------------
# Conv_51
# ['input.159', 'onnx::Conv_531', 'onnx::Conv_532']
# ['input.167']
# ------------------------------------------------------------
# Conv_51
# ['input.159', 'onnx::Conv_531', 'onnx::Conv_532']
# ['input.167']
# ------------------------------------------------------------
# Conv_51
# ['input.159', 'onnx::Conv_531', 'onnx::Conv_532']
# ['input.167']
# ------------------------------------------------------------
# Relu_52
# ['input.167']
# ['onnx::Conv_351']
# ------------------------------------------------------------
# Relu_52
# ['input.167']
# ['onnx::Conv_351']
# ------------------------------------------------------------
# Conv_53
# ['onnx::Conv_351', 'onnx::Conv_534', 'onnx::Conv_535']
# ['onnx::Add_533']
# ------------------------------------------------------------
# Conv_53
# ['onnx::Conv_351', 'onnx::Conv_534', 'onnx::Conv_535']
# ['onnx::Add_533']
# ------------------------------------------------------------
# Conv_53
# ['onnx::Conv_351', 'onnx::Conv_534', 'onnx::Conv_535']
# ['onnx::Add_533']
# ------------------------------------------------------------
# Conv_53
# ['onnx::Conv_351', 'onnx::Conv_534', 'onnx::Conv_535']
# ['onnx::Add_533']
# ------------------------------------------------------------
# Add_54
# ['onnx::Add_533', 'input.159']
# ['onnx::Relu_354']
# ------------------------------------------------------------
# Add_54
# ['onnx::Add_533', 'input.159']
# ['onnx::Relu_354']
# ------------------------------------------------------------
# Add_54
# ['onnx::Add_533', 'input.159']
# ['onnx::Relu_354']
# ------------------------------------------------------------
# Relu_55
# ['onnx::Relu_354']
# ['input.175']
# ------------------------------------------------------------
# Relu_55
# ['onnx::Relu_354']
# ['input.175']
# ------------------------------------------------------------
# Conv_56
# ['input.175', 'onnx::Conv_537', 'onnx::Conv_538']
# ['input.183']
# ------------------------------------------------------------
# Conv_56
# ['input.175', 'onnx::Conv_537', 'onnx::Conv_538']
# ['input.183']
# ------------------------------------------------------------
# Conv_56
# ['input.175', 'onnx::Conv_537', 'onnx::Conv_538']
# ['input.183']
# ------------------------------------------------------------
# Conv_56
# ['input.175', 'onnx::Conv_537', 'onnx::Conv_538']
# ['input.183']
# ------------------------------------------------------------
# Relu_57
# ['input.183']
# ['onnx::Conv_358']
# ------------------------------------------------------------
# Relu_57
# ['input.183']
# ['onnx::Conv_358']
# ------------------------------------------------------------
# Conv_58
# ['onnx::Conv_358', 'onnx::Conv_540', 'onnx::Conv_541']
# ['onnx::Add_539']
# ------------------------------------------------------------
# Conv_58
# ['onnx::Conv_358', 'onnx::Conv_540', 'onnx::Conv_541']
# ['onnx::Add_539']
# ------------------------------------------------------------
# Conv_58
# ['onnx::Conv_358', 'onnx::Conv_540', 'onnx::Conv_541']
# ['onnx::Add_539']
# ------------------------------------------------------------
# Conv_58
# ['onnx::Conv_358', 'onnx::Conv_540', 'onnx::Conv_541']
# ['onnx::Add_539']
# ------------------------------------------------------------
# Add_59
# ['onnx::Add_539', 'input.175']
# ['onnx::Relu_361']
# ------------------------------------------------------------
# Add_59
# ['onnx::Add_539', 'input.175']
# ['onnx::Relu_361']
# ------------------------------------------------------------
# Add_59
# ['onnx::Add_539', 'input.175']
# ['onnx::Relu_361']
# ------------------------------------------------------------
# Relu_60
# ['onnx::Relu_361']
# ['input.191']
# ------------------------------------------------------------
# Relu_60
# ['onnx::Relu_361']
# ['input.191']
# ------------------------------------------------------------
# Conv_61
# ['input.191', 'onnx::Conv_543', 'onnx::Conv_544']
# ['input.199']
# ------------------------------------------------------------
# Conv_61
# ['input.191', 'onnx::Conv_543', 'onnx::Conv_544']
# ['input.199']
# ------------------------------------------------------------
# Conv_61
# ['input.191', 'onnx::Conv_543', 'onnx::Conv_544']
# ['input.199']
# ------------------------------------------------------------
# Conv_61
# ['input.191', 'onnx::Conv_543', 'onnx::Conv_544']
# ['input.199']
# ------------------------------------------------------------
# Relu_62
# ['input.199']
# ['onnx::Conv_365']
# ------------------------------------------------------------
# Relu_62
# ['input.199']
# ['onnx::Conv_365']
# ------------------------------------------------------------
# Conv_63
# ['onnx::Conv_365', 'onnx::Conv_546', 'onnx::Conv_547']
# ['onnx::Add_545']
# ------------------------------------------------------------
# Conv_63
# ['onnx::Conv_365', 'onnx::Conv_546', 'onnx::Conv_547']
# ['onnx::Add_545']
# ------------------------------------------------------------
# Conv_63
# ['onnx::Conv_365', 'onnx::Conv_546', 'onnx::Conv_547']
# ['onnx::Add_545']
# ------------------------------------------------------------
# Conv_63
# ['onnx::Conv_365', 'onnx::Conv_546', 'onnx::Conv_547']
# ['onnx::Add_545']
# ------------------------------------------------------------
# Add_64
# ['onnx::Add_545', 'input.191']
# ['onnx::Relu_368']
# ------------------------------------------------------------
# Add_64
# ['onnx::Add_545', 'input.191']
# ['onnx::Relu_368']
# ------------------------------------------------------------
# Add_64
# ['onnx::Add_545', 'input.191']
# ['onnx::Relu_368']
# ------------------------------------------------------------
# Relu_65
# ['onnx::Relu_368']
# ['input.207']
# ------------------------------------------------------------
# Relu_65
# ['onnx::Relu_368']
# ['input.207']
# ------------------------------------------------------------
# Conv_66
# ['input.207', 'onnx::Conv_549', 'onnx::Conv_550']
# ['input.215']
# ------------------------------------------------------------
# Conv_66
# ['input.207', 'onnx::Conv_549', 'onnx::Conv_550']
# ['input.215']
# ------------------------------------------------------------
# Conv_66
# ['input.207', 'onnx::Conv_549', 'onnx::Conv_550']
# ['input.215']
# ------------------------------------------------------------
# Conv_66
# ['input.207', 'onnx::Conv_549', 'onnx::Conv_550']
# ['input.215']
# ------------------------------------------------------------
# Relu_67
# ['input.215']
# ['onnx::Conv_372']
# ------------------------------------------------------------
# Relu_67
# ['input.215']
# ['onnx::Conv_372']
# ------------------------------------------------------------
# Conv_68
# ['onnx::Conv_372', 'onnx::Conv_552', 'onnx::Conv_553']
# ['onnx::Add_551']
# ------------------------------------------------------------
# Conv_68
# ['onnx::Conv_372', 'onnx::Conv_552', 'onnx::Conv_553']
# ['onnx::Add_551']
# ------------------------------------------------------------
# Conv_68
# ['onnx::Conv_372', 'onnx::Conv_552', 'onnx::Conv_553']
# ['onnx::Add_551']
# ------------------------------------------------------------
# Conv_68
# ['onnx::Conv_372', 'onnx::Conv_552', 'onnx::Conv_553']
# ['onnx::Add_551']
# ------------------------------------------------------------
# Add_69
# ['onnx::Add_551', 'input.207']
# ['onnx::Relu_375']
# ------------------------------------------------------------
# Add_69
# ['onnx::Add_551', 'input.207']
# ['onnx::Relu_375']
# ------------------------------------------------------------
# Add_69
# ['onnx::Add_551', 'input.207']
# ['onnx::Relu_375']
# ------------------------------------------------------------
# Relu_70
# ['onnx::Relu_375']
# ['input.223']
# ------------------------------------------------------------
# Relu_70
# ['onnx::Relu_375']
# ['input.223']
# ------------------------------------------------------------
# Conv_71
# ['input.223', 'onnx::Conv_555', 'onnx::Conv_556']
# ['input.231']
# ------------------------------------------------------------
# Conv_71
# ['input.223', 'onnx::Conv_555', 'onnx::Conv_556']
# ['input.231']
# ------------------------------------------------------------
# Conv_71
# ['input.223', 'onnx::Conv_555', 'onnx::Conv_556']
# ['input.231']
# ------------------------------------------------------------
# Conv_71
# ['input.223', 'onnx::Conv_555', 'onnx::Conv_556']
# ['input.231']
# ------------------------------------------------------------
# Relu_72
# ['input.231']
# ['onnx::Conv_379']
# ------------------------------------------------------------
# Relu_72
# ['input.231']
# ['onnx::Conv_379']
# ------------------------------------------------------------
# Conv_73
# ['onnx::Conv_379', 'onnx::Conv_558', 'onnx::Conv_559']
# ['onnx::Add_557']
# ------------------------------------------------------------
# Conv_73
# ['onnx::Conv_379', 'onnx::Conv_558', 'onnx::Conv_559']
# ['onnx::Add_557']
# ------------------------------------------------------------
# Conv_73
# ['onnx::Conv_379', 'onnx::Conv_558', 'onnx::Conv_559']
# ['onnx::Add_557']
# ------------------------------------------------------------
# Conv_73
# ['onnx::Conv_379', 'onnx::Conv_558', 'onnx::Conv_559']
# ['onnx::Add_557']
# ------------------------------------------------------------
# Conv_74
# ['input.223', 'onnx::Conv_561', 'onnx::Conv_562']
# ['onnx::Add_560']
# ------------------------------------------------------------
# Conv_74
# ['input.223', 'onnx::Conv_561', 'onnx::Conv_562']
# ['onnx::Add_560']
# ------------------------------------------------------------
# Conv_74
# ['input.223', 'onnx::Conv_561', 'onnx::Conv_562']
# ['onnx::Add_560']
# ------------------------------------------------------------
# Conv_74
# ['input.223', 'onnx::Conv_561', 'onnx::Conv_562']
# ['onnx::Add_560']
# ------------------------------------------------------------
# Add_75
# ['onnx::Add_557', 'onnx::Add_560']
# ['onnx::Relu_384']
# ------------------------------------------------------------
# Add_75
# ['onnx::Add_557', 'onnx::Add_560']
# ['onnx::Relu_384']
# ------------------------------------------------------------
# Add_75
# ['onnx::Add_557', 'onnx::Add_560']
# ['onnx::Relu_384']
# ------------------------------------------------------------
# Relu_76
# ['onnx::Relu_384']
# ['input.243']
# ------------------------------------------------------------
# Relu_76
# ['onnx::Relu_384']
# ['input.243']
# ------------------------------------------------------------
# Conv_77
# ['input.243', 'onnx::Conv_564', 'onnx::Conv_565']
# ['input.251']
# ------------------------------------------------------------
# Conv_77
# ['input.243', 'onnx::Conv_564', 'onnx::Conv_565']
# ['input.251']
# ------------------------------------------------------------
# Conv_77
# ['input.243', 'onnx::Conv_564', 'onnx::Conv_565']
# ['input.251']
# ------------------------------------------------------------
# Conv_77
# ['input.243', 'onnx::Conv_564', 'onnx::Conv_565']
# ['input.251']
# ------------------------------------------------------------
# Relu_78
# ['input.251']
# ['onnx::Conv_388']
# ------------------------------------------------------------
# Relu_78
# ['input.251']
# ['onnx::Conv_388']
# ------------------------------------------------------------
# Conv_79
# ['onnx::Conv_388', 'onnx::Conv_567', 'onnx::Conv_568']
# ['onnx::Add_566']
# ------------------------------------------------------------
# Conv_79
# ['onnx::Conv_388', 'onnx::Conv_567', 'onnx::Conv_568']
# ['onnx::Add_566']
# ------------------------------------------------------------
# Conv_79
# ['onnx::Conv_388', 'onnx::Conv_567', 'onnx::Conv_568']
# ['onnx::Add_566']
# ------------------------------------------------------------
# Conv_79
# ['onnx::Conv_388', 'onnx::Conv_567', 'onnx::Conv_568']
# ['onnx::Add_566']
# ------------------------------------------------------------
# Add_80
# ['onnx::Add_566', 'input.243']
# ['onnx::Relu_391']
# ------------------------------------------------------------
# Add_80
# ['onnx::Add_566', 'input.243']
# ['onnx::Relu_391']
# ------------------------------------------------------------
# Add_80
# ['onnx::Add_566', 'input.243']
# ['onnx::Relu_391']
# ------------------------------------------------------------
# Relu_81
# ['onnx::Relu_391']
# ['input.259']
# ------------------------------------------------------------
# Relu_81
# ['onnx::Relu_391']
# ['input.259']
# ------------------------------------------------------------
# Conv_82
# ['input.259', 'onnx::Conv_570', 'onnx::Conv_571']
# ['input.267']
# ------------------------------------------------------------
# Conv_82
# ['input.259', 'onnx::Conv_570', 'onnx::Conv_571']
# ['input.267']
# ------------------------------------------------------------
# Conv_82
# ['input.259', 'onnx::Conv_570', 'onnx::Conv_571']
# ['input.267']
# ------------------------------------------------------------
# Conv_82
# ['input.259', 'onnx::Conv_570', 'onnx::Conv_571']
# ['input.267']
# ------------------------------------------------------------
# Relu_83
# ['input.267']
# ['onnx::Conv_395']
# ------------------------------------------------------------
# Relu_83
# ['input.267']
# ['onnx::Conv_395']
# ------------------------------------------------------------
# Conv_84
# ['onnx::Conv_395', 'onnx::Conv_573', 'onnx::Conv_574']
# ['onnx::Add_572']
# ------------------------------------------------------------
# Conv_84
# ['onnx::Conv_395', 'onnx::Conv_573', 'onnx::Conv_574']
# ['onnx::Add_572']
# ------------------------------------------------------------
# Conv_84
# ['onnx::Conv_395', 'onnx::Conv_573', 'onnx::Conv_574']
# ['onnx::Add_572']
# ------------------------------------------------------------
# Conv_84
# ['onnx::Conv_395', 'onnx::Conv_573', 'onnx::Conv_574']
# ['onnx::Add_572']
# ------------------------------------------------------------
# Add_85
# ['onnx::Add_572', 'input.259']
# ['onnx::Relu_398']
# ------------------------------------------------------------
# Add_85
# ['onnx::Add_572', 'input.259']
# ['onnx::Relu_398']
# ------------------------------------------------------------
# Add_85
# ['onnx::Add_572', 'input.259']
# ['onnx::Relu_398']
# ------------------------------------------------------------
# Relu_86
# ['onnx::Relu_398']
# ['input.275']
# ------------------------------------------------------------
# Relu_86
# ['onnx::Relu_398']
# ['input.275']
# ------------------------------------------------------------
# Conv_87
# ['input.275', 'onnx::Conv_576', 'onnx::Conv_577']
# ['input.283']
# ------------------------------------------------------------
# Conv_87
# ['input.275', 'onnx::Conv_576', 'onnx::Conv_577']
# ['input.283']
# ------------------------------------------------------------
# Conv_87
# ['input.275', 'onnx::Conv_576', 'onnx::Conv_577']
# ['input.283']
# ------------------------------------------------------------
# Conv_87
# ['input.275', 'onnx::Conv_576', 'onnx::Conv_577']
# ['input.283']
# ------------------------------------------------------------
# Relu_88
# ['input.283']
# ['onnx::Concat_402']
# ------------------------------------------------------------
# Relu_88
# ['input.283']
# ['onnx::Concat_402']
# ------------------------------------------------------------
# Conv_89
# ['input.275', 'decoder.aspp.0.convs.1.0.0.weight']
# ['input.287']
# ------------------------------------------------------------
# Conv_89
# ['input.275', 'decoder.aspp.0.convs.1.0.0.weight']
# ['input.287']
# ------------------------------------------------------------
# Conv_89
# ['input.275', 'decoder.aspp.0.convs.1.0.0.weight']
# ['input.287']
# ------------------------------------------------------------
# Conv_90
# ['input.287', 'onnx::Conv_579', 'onnx::Conv_580']
# ['input.295']
# ------------------------------------------------------------
# Conv_90
# ['input.287', 'onnx::Conv_579', 'onnx::Conv_580']
# ['input.295']
# ------------------------------------------------------------
# Conv_90
# ['input.287', 'onnx::Conv_579', 'onnx::Conv_580']
# ['input.295']
# ------------------------------------------------------------
# Conv_90
# ['input.287', 'onnx::Conv_579', 'onnx::Conv_580']
# ['input.295']
# ------------------------------------------------------------
# Relu_91
# ['input.295']
# ['onnx::Concat_406']
# ------------------------------------------------------------
# Relu_91
# ['input.295']
# ['onnx::Concat_406']
# ------------------------------------------------------------
# Conv_92
# ['input.275', 'decoder.aspp.0.convs.2.0.0.weight']
# ['input.299']
# ------------------------------------------------------------
# Conv_92
# ['input.275', 'decoder.aspp.0.convs.2.0.0.weight']
# ['input.299']
# ------------------------------------------------------------
# Conv_92
# ['input.275', 'decoder.aspp.0.convs.2.0.0.weight']
# ['input.299']
# ------------------------------------------------------------
# Conv_93
# ['input.299', 'onnx::Conv_582', 'onnx::Conv_583']
# ['input.307']
# ------------------------------------------------------------
# Conv_93
# ['input.299', 'onnx::Conv_582', 'onnx::Conv_583']
# ['input.307']
# ------------------------------------------------------------
# Conv_93
# ['input.299', 'onnx::Conv_582', 'onnx::Conv_583']
# ['input.307']
# ------------------------------------------------------------
# Conv_93
# ['input.299', 'onnx::Conv_582', 'onnx::Conv_583']
# ['input.307']
# ------------------------------------------------------------
# Relu_94
# ['input.307']
# ['onnx::Concat_410']
# ------------------------------------------------------------
# Relu_94
# ['input.307']
# ['onnx::Concat_410']
# ------------------------------------------------------------
# Conv_95
# ['input.275', 'decoder.aspp.0.convs.3.0.0.weight']
# ['input.311']
# ------------------------------------------------------------
# Conv_95
# ['input.275', 'decoder.aspp.0.convs.3.0.0.weight']
# ['input.311']
# ------------------------------------------------------------
# Conv_95
# ['input.275', 'decoder.aspp.0.convs.3.0.0.weight']
# ['input.311']
# ------------------------------------------------------------
# Conv_96
# ['input.311', 'onnx::Conv_585', 'onnx::Conv_586']
# ['input.319']
# ------------------------------------------------------------
# Conv_96
# ['input.311', 'onnx::Conv_585', 'onnx::Conv_586']
# ['input.319']
# ------------------------------------------------------------
# Conv_96
# ['input.311', 'onnx::Conv_585', 'onnx::Conv_586']
# ['input.319']
# ------------------------------------------------------------
# Conv_96
# ['input.311', 'onnx::Conv_585', 'onnx::Conv_586']
# ['input.319']
# ------------------------------------------------------------
# Relu_97
# ['input.319']
# ['onnx::Concat_414']
# ------------------------------------------------------------
# Relu_97
# ['input.319']
# ['onnx::Concat_414']
# ------------------------------------------------------------
# Shape_98
# ['input.275']
# ['onnx::Gather_415']
# ------------------------------------------------------------
# Shape_98
# ['input.275']
# ['onnx::Gather_415']
# ------------------------------------------------------------
# Constant_99
# []
# ['onnx::Gather_416']
# ------------------------------------------------------------
# Gather_100
# ['onnx::Gather_415', 'onnx::Gather_416']
# ['onnx::Unsqueeze_417']
# ------------------------------------------------------------
# Gather_100
# ['onnx::Gather_415', 'onnx::Gather_416']
# ['onnx::Unsqueeze_417']
# ------------------------------------------------------------
# Gather_100
# ['onnx::Gather_415', 'onnx::Gather_416']
# ['onnx::Unsqueeze_417']
# ------------------------------------------------------------
# Shape_101
# ['input.275']
# ['onnx::Gather_418']
# ------------------------------------------------------------
# Shape_101
# ['input.275']
# ['onnx::Gather_418']
# ------------------------------------------------------------
# Constant_102
# []
# ['onnx::Gather_419']
# ------------------------------------------------------------
# Gather_103
# ['onnx::Gather_418', 'onnx::Gather_419']
# ['onnx::Unsqueeze_420']
# ------------------------------------------------------------
# Gather_103
# ['onnx::Gather_418', 'onnx::Gather_419']
# ['onnx::Unsqueeze_420']
# ------------------------------------------------------------
# Gather_103
# ['onnx::Gather_418', 'onnx::Gather_419']
# ['onnx::Unsqueeze_420']
# ------------------------------------------------------------
# GlobalAveragePool_104
# ['input.275']
# ['input.323']
# ------------------------------------------------------------
# GlobalAveragePool_104
# ['input.275']
# ['input.323']
# ------------------------------------------------------------
# Conv_105
# ['input.323', 'onnx::Conv_588', 'onnx::Conv_589']
# ['input.331']
# ------------------------------------------------------------
# Conv_105
# ['input.323', 'onnx::Conv_588', 'onnx::Conv_589']
# ['input.331']
# ------------------------------------------------------------
# Conv_105
# ['input.323', 'onnx::Conv_588', 'onnx::Conv_589']
# ['input.331']
# ------------------------------------------------------------
# Conv_105
# ['input.323', 'onnx::Conv_588', 'onnx::Conv_589']
# ['input.331']
# ------------------------------------------------------------
# Relu_106
# ['input.331']
# ['x']
# ------------------------------------------------------------
# Relu_106
# ['input.331']
# ['x']
# ------------------------------------------------------------
# Constant_107
# []
# ['onnx::Unsqueeze_425']
# ------------------------------------------------------------
# Unsqueeze_108
# ['onnx::Unsqueeze_417', 'onnx::Unsqueeze_425']
# ['onnx::Concat_426']
# ------------------------------------------------------------
# Unsqueeze_108
# ['onnx::Unsqueeze_417', 'onnx::Unsqueeze_425']
# ['onnx::Concat_426']
# ------------------------------------------------------------
# Unsqueeze_108
# ['onnx::Unsqueeze_417', 'onnx::Unsqueeze_425']
# ['onnx::Concat_426']
# ------------------------------------------------------------
# Constant_109
# []
# ['onnx::Unsqueeze_427']
# ------------------------------------------------------------
# Unsqueeze_110
# ['onnx::Unsqueeze_420', 'onnx::Unsqueeze_427']
# ['onnx::Concat_428']
# ------------------------------------------------------------
# Unsqueeze_110
# ['onnx::Unsqueeze_420', 'onnx::Unsqueeze_427']
# ['onnx::Concat_428']
# ------------------------------------------------------------
# Unsqueeze_110
# ['onnx::Unsqueeze_420', 'onnx::Unsqueeze_427']
# ['onnx::Concat_428']
# ------------------------------------------------------------
# Concat_111
# ['onnx::Concat_426', 'onnx::Concat_428']
# ['onnx::Cast_429']
# ------------------------------------------------------------
# Concat_111
# ['onnx::Concat_426', 'onnx::Concat_428']
# ['onnx::Cast_429']
# ------------------------------------------------------------
# Concat_111
# ['onnx::Concat_426', 'onnx::Concat_428']
# ['onnx::Cast_429']
# ------------------------------------------------------------
# Shape_112
# ['x']
# ['onnx::Slice_430']
# ------------------------------------------------------------
# Shape_112
# ['x']
# ['onnx::Slice_430']
# ------------------------------------------------------------
# Constant_113
# []
# ['onnx::Slice_431']
# ------------------------------------------------------------
# Constant_114
# []
# ['onnx::Slice_432']
# ------------------------------------------------------------
# Constant_115
# []
# ['onnx::Slice_433']
# ------------------------------------------------------------
# Slice_116
# ['onnx::Slice_430', 'onnx::Slice_432', 'onnx::Slice_433', 'onnx::Slice_431']
# ['onnx::Concat_434']
# ------------------------------------------------------------
# Slice_116
# ['onnx::Slice_430', 'onnx::Slice_432', 'onnx::Slice_433', 'onnx::Slice_431']
# ['onnx::Concat_434']
# ------------------------------------------------------------
# Slice_116
# ['onnx::Slice_430', 'onnx::Slice_432', 'onnx::Slice_433', 'onnx::Slice_431']
# ['onnx::Concat_434']
# ------------------------------------------------------------
# Slice_116
# ['onnx::Slice_430', 'onnx::Slice_432', 'onnx::Slice_433', 'onnx::Slice_431']
# ['onnx::Concat_434']
# ------------------------------------------------------------
# Slice_116
# ['onnx::Slice_430', 'onnx::Slice_432', 'onnx::Slice_433', 'onnx::Slice_431']
# ['onnx::Concat_434']
# ------------------------------------------------------------
# Cast_117
# ['onnx::Cast_429']
# ['onnx::Concat_435']
# ------------------------------------------------------------
# Cast_117
# ['onnx::Cast_429']
# ['onnx::Concat_435']
# ------------------------------------------------------------
# Concat_118
# ['onnx::Concat_434', 'onnx::Concat_435']
# ['onnx::Resize_436']
# ------------------------------------------------------------
# Concat_118
# ['onnx::Concat_434', 'onnx::Concat_435']
# ['onnx::Resize_436']
# ------------------------------------------------------------
# Concat_118
# ['onnx::Concat_434', 'onnx::Concat_435']
# ['onnx::Resize_436']
# ------------------------------------------------------------
# Resize_119
# ['x', '', '', 'onnx::Resize_436']
# ['onnx::Concat_439']
# ------------------------------------------------------------
# Resize_119
# ['x', '', '', 'onnx::Resize_436']
# ['onnx::Concat_439']
# ------------------------------------------------------------
# Resize_119
# ['x', '', '', 'onnx::Resize_436']
# ['onnx::Concat_439']
# ------------------------------------------------------------
# Resize_119
# ['x', '', '', 'onnx::Resize_436']
# ['onnx::Concat_439']
# ------------------------------------------------------------
# Resize_119
# ['x', '', '', 'onnx::Resize_436']
# ['onnx::Concat_439']
# ------------------------------------------------------------
# Concat_120
# ['onnx::Concat_402', 'onnx::Concat_406', 'onnx::Concat_410', 'onnx::Concat_414', 'onnx::Concat_439']
# ['input.335']
# ------------------------------------------------------------
# Concat_120
# ['onnx::Concat_402', 'onnx::Concat_406', 'onnx::Concat_410', 'onnx::Concat_414', 'onnx::Concat_439']
# ['input.335']
# ------------------------------------------------------------
# Concat_120
# ['onnx::Concat_402', 'onnx::Concat_406', 'onnx::Concat_410', 'onnx::Concat_414', 'onnx::Concat_439']
# ['input.335']
# ------------------------------------------------------------
# Concat_120
# ['onnx::Concat_402', 'onnx::Concat_406', 'onnx::Concat_410', 'onnx::Concat_414', 'onnx::Concat_439']
# ['input.335']
# ------------------------------------------------------------
# Concat_120
# ['onnx::Concat_402', 'onnx::Concat_406', 'onnx::Concat_410', 'onnx::Concat_414', 'onnx::Concat_439']
# ['input.335']
# ------------------------------------------------------------
# Concat_120
# ['onnx::Concat_402', 'onnx::Concat_406', 'onnx::Concat_410', 'onnx::Concat_414', 'onnx::Concat_439']
# ['input.335']
# ------------------------------------------------------------
# Conv_121
# ['input.335', 'onnx::Conv_591', 'onnx::Conv_592']
# ['input.343']
# ------------------------------------------------------------
# Conv_121
# ['input.335', 'onnx::Conv_591', 'onnx::Conv_592']
# ['input.343']
# ------------------------------------------------------------
# Conv_121
# ['input.335', 'onnx::Conv_591', 'onnx::Conv_592']
# ['input.343']
# ------------------------------------------------------------
# Conv_121
# ['input.335', 'onnx::Conv_591', 'onnx::Conv_592']
# ['input.343']
# ------------------------------------------------------------
# Relu_122
# ['input.343']
# ['input.347']
# ------------------------------------------------------------
# Relu_122
# ['input.343']
# ['input.347']
# ------------------------------------------------------------
# Conv_123
# ['input.347', 'decoder.aspp.1.0.weight']
# ['input.351']
# ------------------------------------------------------------
# Conv_123
# ['input.347', 'decoder.aspp.1.0.weight']
# ['input.351']
# ------------------------------------------------------------
# Conv_123
# ['input.347', 'decoder.aspp.1.0.weight']
# ['input.351']
# ------------------------------------------------------------
# Conv_124
# ['input.351', 'onnx::Conv_594', 'onnx::Conv_595']
# ['input.359']
# ------------------------------------------------------------
# Conv_124
# ['input.351', 'onnx::Conv_594', 'onnx::Conv_595']
# ['input.359']
# ------------------------------------------------------------
# Conv_124
# ['input.351', 'onnx::Conv_594', 'onnx::Conv_595']
# ['input.359']
# ------------------------------------------------------------
# Conv_124
# ['input.351', 'onnx::Conv_594', 'onnx::Conv_595']
# ['input.359']
# ------------------------------------------------------------
# Relu_125
# ['input.359']
# ['input.363']
# ------------------------------------------------------------
# Relu_125
# ['input.359']
# ['input.363']
# ------------------------------------------------------------
# Resize_126
# ['input.363', '', 'onnx::Resize_602']
# ['onnx::Concat_452']
# ------------------------------------------------------------
# Resize_126
# ['input.363', '', 'onnx::Resize_602']
# ['onnx::Concat_452']
# ------------------------------------------------------------
# Resize_126
# ['input.363', '', 'onnx::Resize_602']
# ['onnx::Concat_452']
# ------------------------------------------------------------
# Resize_126
# ['input.363', '', 'onnx::Resize_602']
# ['onnx::Concat_452']
# ------------------------------------------------------------
# Conv_127
# ['input.55', 'onnx::Conv_597', 'onnx::Conv_598']
# ['input.371']
# ------------------------------------------------------------
# Conv_127
# ['input.55', 'onnx::Conv_597', 'onnx::Conv_598']
# ['input.371']
# ------------------------------------------------------------
# Conv_127
# ['input.55', 'onnx::Conv_597', 'onnx::Conv_598']
# ['input.371']
# ------------------------------------------------------------
# Conv_127
# ['input.55', 'onnx::Conv_597', 'onnx::Conv_598']
# ['input.371']
# ------------------------------------------------------------
# Relu_128
# ['input.371']
# ['onnx::Concat_455']
# ------------------------------------------------------------
# Relu_128
# ['input.371']
# ['onnx::Concat_455']
# ------------------------------------------------------------
# Concat_129
# ['onnx::Concat_452', 'onnx::Concat_455']
# ['input.375']
# ------------------------------------------------------------
# Concat_129
# ['onnx::Concat_452', 'onnx::Concat_455']
# ['input.375']
# ------------------------------------------------------------
# Concat_129
# ['onnx::Concat_452', 'onnx::Concat_455']
# ['input.375']
# ------------------------------------------------------------
# Conv_130
# ['input.375', 'decoder.block2.0.0.weight']
# ['input.379']
# ------------------------------------------------------------
# Conv_130
# ['input.375', 'decoder.block2.0.0.weight']
# ['input.379']
# ------------------------------------------------------------
# Conv_130
# ['input.375', 'decoder.block2.0.0.weight']
# ['input.379']
# ------------------------------------------------------------
# Conv_131
# ['input.379', 'onnx::Conv_600', 'onnx::Conv_601']
# ['input.387']
# ------------------------------------------------------------
# Conv_131
# ['input.379', 'onnx::Conv_600', 'onnx::Conv_601']
# ['input.387']
# ------------------------------------------------------------
# Conv_131
# ['input.379', 'onnx::Conv_600', 'onnx::Conv_601']
# ['input.387']
# ------------------------------------------------------------
# Conv_131
# ['input.379', 'onnx::Conv_600', 'onnx::Conv_601']
# ['input.387']
# ------------------------------------------------------------
# Relu_132
# ['input.387']
# ['input.391']
# ------------------------------------------------------------
# Relu_132
# ['input.387']
# ['input.391']
# ------------------------------------------------------------
# Conv_133
# ['input.391', 'segmentation_head.0.weight', 'segmentation_head.0.bias']
# ['input.395']
# ------------------------------------------------------------
# Conv_133
# ['input.391', 'segmentation_head.0.weight', 'segmentation_head.0.bias']
# ['input.395']
# ------------------------------------------------------------
# Conv_133
# ['input.391', 'segmentation_head.0.weight', 'segmentation_head.0.bias']
# ['input.395']
# ------------------------------------------------------------
# Conv_133
# ['input.391', 'segmentation_head.0.weight', 'segmentation_head.0.bias']
# ['input.395']
# ------------------------------------------------------------
# Resize_134
# ['input.395', '', 'onnx::Resize_603']
# ['output']
# ------------------------------------------------------------
# Resize_134
# ['input.395', '', 'onnx::Resize_603']
# ['output']
# ------------------------------------------------------------
# Resize_134
# ['input.395', '', 'onnx::Resize_603']
# ['output']
# ------------------------------------------------------------
# Resize_134
# ['input.395', '', 'onnx::Resize_603']
# ['output']
# ------------------------------------------------------------
# name: "input"
# type {
#   tensor_type {
#     elem_type: 1
#     shape {
#       dim {
#         dim_param: "batch_size"
#       }
#       dim {
#         dim_value: 3
#       }
#       dim {
#         dim_value: 512
#       }
#       dim {
#         dim_value: 512
#       }
#     }
#   }
# }
#
# ------------------------------------------------------------
# name: "output"
# type {
#   tensor_type {
#     elem_type: 1
#     shape {
#       dim {
#         dim_param: "batch_size"
#       }
#       dim {
#         dim_param: "Resizeoutput_dim_1"
#       }
#       dim {
#         dim_param: "Resizeoutput_dim_2"
#       }
#       dim {
#         dim_param: "Resizeoutput_dim_3"
#       }
#     }
#   }
# }
